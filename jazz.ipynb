# %%
import pandas as pd

df = pd.read_csv("patrioticjazzthelox_7-04_guests.csv")
df
# Out:
#                           Name    Status  Plus ones            RSVP date  \
# 0                        Aaron     Maybe        1.0  2025-07-01 04:40:24
# 1                        Aaron   Invited        NaN                  NaN
# 2   Antonio Alonso Montealegre     Going        NaN  2025-07-01 16:35:55
# 3                Bridgette Wu    Invited        NaN                  NaN
# 4                       Brooks     Maybe        NaN  2025-07-01 16:02:53
# 5                  David Corbo   Invited        NaN                  NaN
# 6                  Dawn Sheedy   Invited        NaN                  NaN
# 7                        Diana  Can't Go        NaN  2025-07-04 00:32:39
# 8                       Hayden     Going        NaN  2025-07-02 07:03:56
# 9                Isaac Feldman   Invited        NaN                  NaN
# 10              James Mchargue   Invited        NaN                  NaN
# 11              John Farnandez   Invited        NaN                  NaN
# ...

# %%
import matplotlib.pyplot as plt

df_jazz = df["ya like jazz?"].dropna()
plt.pie(df_jazz.value_counts().values, labels=["bee", "ball"], autopct=lambda p: (p / 100) * len(df_jazz))
# Out:
# ([<matplotlib.patches.Wedge at 0x115da5e70>,
# ...
#  [Text(-0.7778174639428924, 0.7778174546675123, 'bee'),
#   Text(0.7778177173879477, -0.7778172012223713, 'ball')],
#  [Text(-0.4242640712415776, 0.42426406618227935, '6.0'),
#   Text(0.4242642094843351, -0.42426392793947526, '2.0')])
